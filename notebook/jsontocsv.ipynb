# %% [markdown]
# # **JSON to CSV**

# %%
import json
import pandas as pd

# %%
with open("./data_resto_unair.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                          title price    categoryName  \
# 0       Bakso CITRA SATU PUTRA  None  Restoran Bakso
# 1     Bakso asli solo Pak Tono  None  Restoran Bakso
# 2              Bakso Pak Anton  None  Restoran Bakso
# 3            Bakso Kepala Sapi  None  Restoran Bakso
# 4  Warung Bakso Dan Mie Wijaya  None  Restoran Bakso
#
#                                              address  \
# 0  Jl. Raya Mulyosari No.177-179, Kalisari, Kec. ...
# 1  Jl. Gebang Lor No.49, Gebang Putih, Kec. Sukol...
# 2  Jl. Wisma Permai Tengah I No.CC-21, Kejawaan P...
# 3  Jl. Klampis Jaya No.47, Klampis Ngasem, Kec. S...
# 4  Jl. Mulyorejo Tengah No.73, Mulyorejo, Kec. Mu...
#
#                                 neighborhood  \
# 0              Kalisari, Kecamatan Mulyorejo
# 1           Gebang Putih, Kecamatan Sukolilo
# 2  Kejawaan Putih Tamba, Kecamatan Mulyorejo
# 3         Klampis Ngasem, Kecamatan Sukolilo
# 4             Mulyorejo, Kecamatan Mulyorejo
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   686 non-null    object
#  1   price                   163 non-null    object
#  2   categoryName            686 non-null    object
#  3   address                 686 non-null    object
#  4   neighborhood            686 non-null    object
#  5   street                  681 non-null    object
#  6   city                    686 non-null    object
#  7   postalCode              680 non-null    object
#  8   state                   686 non-null    object
#  9   countryCode             686 non-null    object
#  10  claimThisBusiness       686 non-null    bool
#  11  location                686 non-null    object
#  12  totalScore              681 non-null    float64
#  13  permanentlyClosed       686 non-null    bool
# ...

# %%
df.isnull().sum()
# Out:
# title                       0
# price                     523
# categoryName                0
# address                     0
# neighborhood                0
# street                      5
# city                        0
# postalCode                  6
# state                       0
# countryCode                 0
# claimThisBusiness           0
# location                    0
# totalScore                  5
# permanentlyClosed           0
# temporarilyClosed           0
# placeId                     0
# categories                  0
# fid                         0
# cid                         0
# reviewsCount                0
# imagesCount                 0
# imageCategories             0
# scrapedAt                   0
# googleFoodUrl             686
# hotelAds                    0
# openingHours                0
# peopleAlsoSearch            0
# placesTags                  0
# reviewsTags                 0
# additionalInfo              5
# gasPrices                   0
# ...

# %%
df.isna().sum()
# Out:
# title                       0
# price                     523
# categoryName                0
# address                     0
# neighborhood                0
# street                      5
# city                        0
# postalCode                  6
# state                       0
# countryCode                 0
# claimThisBusiness           0
# location                    0
# totalScore                  5
# permanentlyClosed           0
# temporarilyClosed           0
# placeId                     0
# categories                  0
# fid                         0
# cid                         0
# reviewsCount                0
# imagesCount                 0
# imageCategories             0
# scrapedAt                   0
# googleFoodUrl             686
# hotelAds                    0
# openingHours                0
# peopleAlsoSearch            0
# placesTags                  0
# reviewsTags                 0
# additionalInfo              5
# gasPrices                   0
# ...

# %%
df
# Out:
#                            title price    categoryName  \
# 0         Bakso CITRA SATU PUTRA  None  Restoran Bakso
# 1       Bakso asli solo Pak Tono  None  Restoran Bakso
# 2                Bakso Pak Anton  None  Restoran Bakso
# 3              Bakso Kepala Sapi  None  Restoran Bakso
# 4    Warung Bakso Dan Mie Wijaya  None  Restoran Bakso
# ..                           ...   ...             ...
# 681                  WARKOP 3000  None            Kafe
# 682         Warkop 78 & TOKO IVA  None      Kedai Kopi
# 683                  Warkop R-11  None      Kedai Kopi
# 684                   Warkop DKN     $      Kedai Kopi
# 685               Warkop Lestari  None      Kedai Kopi
#
#                                                address  \
# 0    Jl. Raya Mulyosari No.177-179, Kalisari, Kec. ...
# 1    Jl. Gebang Lor No.49, Gebang Putih, Kec. Sukol...
# 2    Jl. Wisma Permai Tengah I No.CC-21, Kejawaan P...
# 3    Jl. Klampis Jaya No.47, Klampis Ngasem, Kec. S...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   686 non-null    object
#  1   price                   163 non-null    object
#  2   categoryName            686 non-null    object
#  3   address                 686 non-null    object
#  4   neighborhood            686 non-null    object
#  5   street                  681 non-null    object
#  6   city                    686 non-null    object
#  7   postalCode              680 non-null    object
#  8   state                   686 non-null    object
#  9   countryCode             686 non-null    object
#  10  claimThisBusiness       686 non-null    bool
#  11  location                686 non-null    object
#  12  totalScore              681 non-null    float64
#  13  permanentlyClosed       686 non-null    bool
# ...

# %%
df = df[['title', 'address', 'totalScore', 'categories', 'location' ]]

# %%
df
# Out:
#                            title  \
# 0         Bakso CITRA SATU PUTRA
# 1       Bakso asli solo Pak Tono
# 2                Bakso Pak Anton
# 3              Bakso Kepala Sapi
# 4    Warung Bakso Dan Mie Wijaya
# ..                           ...
# 681                  WARKOP 3000
# 682         Warkop 78 & TOKO IVA
# 683                  Warkop R-11
# 684                   Warkop DKN
# 685               Warkop Lestari
#
#                                                address  totalScore  \
# 0    Jl. Raya Mulyosari No.177-179, Kalisari, Kec. ...         4.7
# 1    Jl. Gebang Lor No.49, Gebang Putih, Kec. Sukol...         4.5
# 2    Jl. Wisma Permai Tengah I No.CC-21, Kejawaan P...         4.8
# 3    Jl. Klampis Jaya No.47, Klampis Ngasem, Kec. S...         4.3
# 4    Jl. Mulyorejo Tengah No.73, Mulyorejo, Kec. Mu...         4.5
# ..                                                 ...         ...
# 681  Jl. Semolowaru No.44, Semolowaru, Kec. Sukolil...         4.4
# ...

# %%
df.isnull().sum()
# Out:
# title         0
# address       0
# totalScore    5
# categories    0
# location      0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681 entries, 0 to 685
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       681 non-null    object
#  1   address     681 non-null    object
#  2   totalScore  681 non-null    float64
#  3   categories  681 non-null    object
#  4   location    681 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 31.9+ KB

# %%
df.to_csv("Dataset_Resto_Unair.csv", index= False)
