# %% [markdown]
# # **Preprocessing Data**

# %%
#import library
import pandas as pd
import numpy as np
import re
import ast
from haversine import haversine, Unit
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import joblib

# %%
#load data
data = ("./data/Dataset_Resto_Unair.csv")
df = pd.read_csv(data)

# %%
df.head()
# Out:
#                          title  \
# 0       Bakso CITRA SATU PUTRA
# 1     Bakso asli solo Pak Tono
# 2              Bakso Pak Anton
# 3            Bakso Kepala Sapi
# 4  Warung Bakso Dan Mie Wijaya
#
#                                              address  totalScore  \
# 0  Jl. Raya Mulyosari No.177-179, Kalisari, Kec. ...         4.7
# 1  Jl. Gebang Lor No.49, Gebang Putih, Kec. Sukol...         4.5
# 2  Jl. Wisma Permai Tengah I No.CC-21, Kejawaan P...         4.8
# 3  Jl. Klampis Jaya No.47, Klampis Ngasem, Kec. S...         4.3
# 4  Jl. Mulyorejo Tengah No.73, Mulyorejo, Kec. Mu...         4.5
#
#                            categories                                 location
# 0                  ['Restoran Bakso']  {'lat': -7.2707337, 'lng': 112.7969433}
# 1                  ['Restoran Bakso']  {'lat': -7.2812233, 'lng': 112.7873977}
# 2   ['Restoran Bakso', 'Rumah Makan']  {'lat': -7.2741205, 'lng': 112.7868231}
# 3                  ['Restoran Bakso']    {'lat': -7.28232, 'lng': 112.7763487}
# 4  ['Restoran Bakso', 'Restoran Mie']  {'lat': -7.2678847, 'lng': 112.7780222}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       681 non-null    object
#  1   address     681 non-null    object
#  2   totalScore  681 non-null    float64
#  3   categories  681 non-null    object
#  4   location    681 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 26.7+ KB

# %%
df.isnull().sum()
# Out:
# title         0
# address       0
# totalScore    0
# categories    0
# location      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#        totalScore
# count  681.000000
# mean     4.569457
# std      0.366551
# min      1.800000
# 25%      4.400000
# 50%      4.600000
# 75%      4.800000
# max      5.000000

# %% [markdown]
# # Preprocessing Data Categories

# %%
df['categories']
# Out:
# 0                      ['Restoran Bakso']
# 1                      ['Restoran Bakso']
# 2       ['Restoran Bakso', 'Rumah Makan']
# 3                      ['Restoran Bakso']
# 4      ['Restoran Bakso', 'Restoran Mie']
#                       ...
# 676                              ['Kafe']
# 677                        ['Kedai Kopi']
# 678                        ['Kedai Kopi']
# 679                        ['Kedai Kopi']
# 680                        ['Kedai Kopi']
# Name: categories, Length: 681, dtype: object

# %%
def remove_symbol(text):
    joined = ' '.join(text)
    cleaned_text = re.sub(r'[^A-Za-z\s]','',text)
    return cleaned_text

# %%
df['categories'] = df['categories'].apply(remove_symbol)

# %%
df['title'].tolist()
# Out:
# ['Bakso CITRA SATU PUTRA',
#  'Bakso asli solo Pak Tono',
#  'Bakso Pak Anton',
#  'Bakso Kepala Sapi',
#  'Warung Bakso Dan Mie Wijaya',
#  'Bakso & Mie Bondowoso',
#  'Bakso Pangsit Mie Ayam Sensasi Rasa',
#  'Bakso Dan Mie Ayam "Barokah"',
#  'Bakso Solo Goyang Lidah (GOLI)',
#  'Bakso Bem',
#  'Bakso Solo Cak Awi',
#  'Bakso jumbo sinar baru 2',
#  'Bakso bratang Pindahan (ITATS)',
#  'Warung LA',
#  'Warung Kampus',
#  'Warung Mbak Khol',
#  'Warung Pak No Lamongan. ( Penyetan & Nasi Goreng )',
#  'Warung Bagus',
#  'Warung Makan Bu Yati',
#  'Warung Sultan',
#  'Warung Emak Murah Enak',
#  'Warung Cak Nari Munos',
#  'Warung Mbak Sieh',
#  'Warung Penyetan Pak Kumis',
#  'Warung Cak Di',
#  'Warung Bu Warni Surabaya ( Nasi Petis-Specialist Cumi Hitam)',
#  'Warung Satria',
#  'Warung Mami 88',
#  'Warung LA 2',
#  'Bakso Daging Sapi Pak Sabar',
#  'Bakso Bonnet',
#  'Bakso Pak Djo',
#  'Bakso Daging Sapi P.Sabar',
#  'Bakso Pak War',
#  'Bakso Pak Pek',
#  'Mie Ayam & Bakso Solo',
#  'Warung Tegal Gebang',
#  'Warung Fadhila',
#  'Warung Pak Hasyim',
#  'Warung Mak Ni',
#  'Warung Makan Tegal Aero',
#  'Warung Mama Titik',
#  'Warung KANE',
#  'Warung Solo',
#  'Warung Ijo Menur Pumpungan',
#  'Warung Nasi Gudeg Bu Arif Prasmanan',
#  'Warung Seafood Pucang',
#  'Warung Gresik Mbak Vien',
#  'Warung Rawon 48',
#  'Warung Sederhana Gebang Wetan',
#  'Warung Leko Manyar',
#  'Warung Lestari',
#  'Warung Kuning - Kalibokor',
#  'Warung Bu Siswo',
#  'Warung nasi jakarta',
#  'Warung Nanda',
#  'Warung Bu Kris',
#  'Warung Mak Eco',
#  'Warung Emak Keputih',
#  'Bakso Ambon Nginden',
#  'Bakso Pak.No',
#  'Bakso Merr99',
#  'PRODUSEN BAKSO',
#  'Bakso & Mie Ayam Cak Nur',
#  'Bakso Unyil',
#  "Bakso super urat mbok'e nindi",
#  'Bakso Cak Nur 1',
#  'Bakso Cak Mus Airlangga',
#  'Bakso Pak Nan',
#  'BAKSO SOLMED 168',
#  'Warung Larris San Antonio',
#  'Warung Mbak Lies',
#  'Warung Sari Laut Bu Mis Santoso',
#  'Warung Bibik Pojok',
#  'WARUNG Oemik Ika SURABAYA',
#  'Warung Damai',
#  'Mie Mapan - Barata Jaya',
#  'Warung Desa',
#  'Warung Prasmanan Soponyono Nasi kotak, Tumpeng, catering kantor dan Prasmanan',
#  'Warung Mas Ayok',
#  'Warung Abah',
#  'Bakso dan Mie Pitik Barcelona',
#  'Bakso Pak Kumis',
#  'Bakso Pak Sarjuk',
#  'Bakso Rama',
#  'Bakso Pak LaLa',
#  'Bakso Mercon Xing Eco',
#  'Bakso Solo Samrat Manyar Kertoarjo',
#  'Bakso Bratang',
#  'Bakso Mas Roy',
#  'Bakso Omen Again',
#  'Bakso Tombo Luwe, Mie Ayam dan Es Campur semolowaru',
#  'Bakso Royal',
#  'Bakso Bandung Mamang',
#  'Bakso Pak Min, Merr',
#  'BAKSO CAKSUM KHAS DJAKARTA',
#  'Bakso Manyar Tirtoyoso "Pink"',
#  'Governor "Kedai Bakso"',
#  'Bakso dan Mie Ayam Langgeng Jaya',
#  'BAKSO BALUNGAN / SOTO AYAM',
#  'PENYETAN OM ANDRE',
#  'Penyetan Cok Pakuwon City Mall',
#  'Penyetan Jhon Mudah Barokah',
#  'Penyetan Cak Thofa',
#  'Penyetan nasi uduk cak lut',
#  'Depot Penyetan Cak Herry',
#  'penyetan \'UPIK JAYA"',
#  'Penyetan Mas Brooo spesial pedas',
#  'Mr. Waras - Nasi Uduk Nganjuk & Penyetan',
#  'Penyetan Cak Kabul',
#  'Penyetan Sambel Uleg Dhe Sri',
#  'Penyetan Bu Yanti',
#  'Geprek dan Penyetan Sambel Cowek',
#  'Penyetan barokah dua saudara',
#  'Tempe Penyet C - Ho',
#  'Penyetan Cak Dodik Karang Menjangan',
#  'Mbok Sil Penyetan Sambel Tempong',
#  'Aneka Penyetan Cak Mat',
#  'WARUNG PENYETAN " ETAN POM "',
#  'Sego Sambel Cak Nur - Penyetan',
#  'Penyetan 77 - Jojoran',
#  'Penyetan Pak Put',
#  'Penyetan " CAH MENUR "',
#  'Penyetan Sambel Teri Cak Har',
#  'Penyetan Indah',
#  'Ayam Geprek Bangsus',
#  'Ayam Geprek Mr Suprek Koni',
#  'Mr Suprek - Keputih',
#  'Sambelan Geprek Seafood Joder ka Dhani',
#  'Geprek Rakyat - Sukolilo',
#  'Geprek Gepruk',
#  'Geprek AG',
#  'Ayam Geprek Sambat',
#  'Geprek ronggolawe',
#  'Ayam Geprek Dombleh',
#  'Ayam Geprek Cak Lawaz',
#  'Geprek Bang',
#  'Geprek ONE',
#  'AYAM GEPREK MBAK LIEK',
#  'Penyetan Watu Uleg',
#  'WARUNG PENYETAN MERDEKA',
#  'Penyetan Cak Ganul',
#  'Penyetan "Sido Makmur"',
#  'Penyetan Mak Tene By Mas Boy',
#  'Penyetan mbak yun',
#  'JAYA PENYETAN (BELUT & WADER)',
#  'Warung Penyetan Nganjuk',
#  'Penyetan Nyamleng "Mbak Upik"',
#  'Penyetan & Bebek 2x2',
#  'Telur puyuh dan penyetan berkah',
#  'Warung ikhwan Penyetan',
#  'Warung Penyetan Mama Cab.Baratajaya',
#  'Penyetan Mamake KM 39x',
#  'Ayam Geprek Mr Suprek - Dharmawangsa',
#  'Ayam Geprek Gold Chick Dharmawangsa',
#  'Ayam Geprek Mbok Dhewor',
#  'Ayam Geprek Untag mr suprek',
#  'Ayam geprek nglampang cabang gubeng',
#  'Ayam geprek mantap',
#  'Babaqu capcin & ayam Geprek',
#  'KEBAB MONTU & GEPREK',
#  'Gepruk Geprek Karang Menjangan',
#  'Penyetan geprek wong meduro',
#  'Penyetan Pecok 69',
#  'Sego Penyetan Kedai Chef Onel',
#  'Penyetan Sugio',
#  'Penyetan Sambal Teri Mas Sugeng',
#  'Warung Penyetan Sederhana',
#  'Penyetan Sederhana MAS RAFFA',
#  'Penyetan mas agus',
#  'Penyetan Bu Yuli Mulyorejo',
#  'Spesialis Sambel Penyetan',
#  'Penyetan Airlangga Cab. 2',
#  'Ayam Geprek vs Seblak Jagor 313',
#  'Ayam Geprek Moome Gubeng',
#  'Ayam Geprek OHyes',
#  "Ayam Geprek Mak'E",
#  'DNL GEPREK SURABAYA',
#  'Geprek Memories',
#  'Geprek Gold Chick - Nginden Semolo',
#  'Ayam Geprek JINGKRAK',
#  'geprek tante vokasi',
#  'Nasi Goreng Cak Nur',
#  'PADANGNESIAN - Nasi Goreng Pedas Padang',
#  'Nasi Goreng 99 Pak Nali',
#  'Nasi Goreng Ayam Kecap Pak Di',
#  'Nasi Goreng Jagad 25',
#  'Soto Ayam & Nasi Goreng Jawa Cak Lim',
#  'Depot Nasi Campur Pak Salim',
#  'NASI GORENG Jawa Cak ALI',
#  'Nasi Goreng Jawa (Cak Sul)',
#  'Nasi Goreng Surabaya',
#  'Nasi Goreng & Mie Pelangi Cak Tro',
#  'Nasi Goreng Pak Tohir',
#  'GEPREK AIRLANGGA',
#  'Geprek mbok imee',
#  'Ayam Geprek Sedulur 4',
#  'AYAM GEPREK JURAGAN KERTA ADI',
#  'Ayam geprek and jus Sukesi',
#  'SWAG Warung Ayam Geprek',
#  "AYAM GEPREK D'BAKAR",
#  'Geprek Josspolll Gebang Putih',
#  'AYAM GEPREK MAMA',
#  'Universitas Ayam Geprek',
#  'Ayam Geprek 4G',
#  'Geprek B3NSU',
#  'Ayam Geprek Bee & Lee Surabaya',
#  'Penyetan geprek Nyinyir dan Bakoel susu',
#  'Nasi Goreng Cak Ji',
#  'Nasi Goreng UGD+',
#  'Nasi babat emak',
#  'Nasi Goreng Pak No',
#  'Nasi Bakar Kamput',
#  'Nasi Pecel Cak Iwan',
#  'Nasi Goreng Pak Ali',
#  'Nasi Goreng Rempah Ngocol',
#  'Nasi Goreng SEMPAL',
#  'Nasi Goreng Dok Dok',
#  'Ayam Geprek JN Jaman Now',
#  'KAG - Kakkk Ayam Geprek!!!, Dharmawangsa',
#  'Warung Geprek CK',
#  'Ayam Geprek Mang Soetta keputih',
#  'Nasi Goreng Jawa CAK TO',
#  'Nasi Goreng Jawa Bu Pardji',
#  'NASI GORENG RASA KAMPUNG',
#  'Nasi Campur Kertajaya Indah',
#  'Nasi Goreng Pak Karto',
#  'Nasi goreng jawa BARATA bratang',
#  'Depot nasi campur pojok tambak bayan',
#  "Nasi Goreng Cak Pi'i",
#  'Nasi Goreng & Mie Goreng Cak Aris 02',
#  'Nasi Tempong Sri Dewi',
#  'Nasi Goreng Bonek',
#  'Nasi kebuli La Tahzan khas Ampel cabang karmen',
#  'Mie Ayam Pak Tris dan Nasi Goreng Sebelahe Pak Tris',
#  'Nasi Goreng Pak Ndut',
#  'Nasi goreng Cak To',
#  'Nasi Goreng Master, Keputih',
#  'Nasi goreng jawa Pak Dul',
#  'Nasi Goreng King',
#  'Depot Nasi Goreng Jakarta',
#  'warung Nasi Goreng Pak Bro',
#  'Mie Ayam Nusantara',
#  'Mie Gacoan - Manyar Kertoarjo 3',
#  'Mie Oke - Keputih Tegal',
#  'Mie Ayam Cak Wi',
#  'Pangsit Mie & Bakwan Mentari',
#  'Mie Ayam Putri Kembar',
#  'Mie Toree',
#  'Pangsit Mie Ayam Jakarta Gebang Putih',
#  'Mie Gacoan - Ir Soekarno',
#  'Mie Ayam Bengawan',
#  'Mie Rajawali',
#  'Pangsit Mie Ayam Jakarta Klampis',
#  'Ada Apa Dengan Kopi (AADK)',
#  'KOPI BUJEND',
#  'Kopi Titik Koma - San Antonio',
#  'Biji Kopi',
#  'PAPER CUP COFFEE MANYAR',
#  'Kopi Giras 71',
#  'TYE Coffee House',
#  'Kopi Konnichiwa Dharmahusada',
#  'Kopi Kuto',
#  'Kopi Kenangan - The Avenue MERR',
#  'kopi bonsai',
#  'RKM noodle house & coffee',
#  'KEDAI KOPI SUPER',
#  'Kedai Tentrem',
#  'Titik Terang Kopi',
#  'Kampung Kopi',
#  'Asana kopi',
#  'Pangsit Mie UP Pak Tatung',
#  'Mie Pangsit Nginden Raya Khas Makasar',
#  'Mie Ayam Puas',
#  'Pangsit Mie Ujung Pandang (BABI)',
#  'Mie Ayam Jakarta PAK DOEL',
#  'Mie Goreng Jawa',
#  'MIE AYAM KARE MAS ODIE',
#  'Pangsit Mie Ayam Jakarta Depot Rizky',
#  'Pangsit Mie Up Pak Kumis',
#  'Mie Ayam 5000 - Kertajaya',
#  'Warung nasi budhe',
#  'Warung Nasi Shofi',
#  'Nasi Padang Uda Wandi 2 Surabaya',
#  'Nasi Pecel Safira',
#  'Nasi Padang Uda Wandi Surabaya',
#  'WARUNG Nasi Campur "bu sri klampis"',
#  'Nasi Goreng Kantor Pos Pucang',
#  'Nasi goreng 88',
#  'Kopi Kakak - Pucang Anom Timur',
#  'Toko Kopi Berkah Jaya',
#  'Kopilaborasi',
#  'Pukul Satu Kopi - Dharmawangsa',
#  'Toko Kopi Karmen',
#  'Kopi Vator',
#  'Katalokopi',
#  'Kopi Kenangan - Ruko Ngagel',
#  'Toko Kopi Sepakat Gubeng',
#  'Mie Ayam Jamboel "Spesial : Telur, Ceker , Kepala ".',
#  'Mie Ayam BAROKAH "PAK SUMALI"',
#  'Depot Nain',
#  'PANGSIT MIE AYAM JAKARTA "CAK SUR"',
#  'Pangsit Mie Makassar',
#  'MIE GNI Jember',
#  'Depot Mie Kocok Aceh',
#  'Mie Ayam Jakarta Bang Rudy',
#  'Pangsit Mie Ayam Pak No',
#  'Mie Ayam & Bakso Wong Solo - Manyar Kartika',
#  'Warung Pangsit Mie Ayam Jakarta',
#  'Mie Manyar 99',
#  'Mie Restu Bang Karman',
#  '" STK " Sedulur Tunggal Kopi (STK MULYOSARI)',
#  'Rumah Kopi Baik',
#  'Kedai Kopi 32',
#  'Mokhabika Coffee',
#  'Kopi Mama Ury',
#  'Distrik Kopi',
#  'Kopi Kenangan - Ruko Manyar',
#  'Philip’s Coffee San Antonio',
#  'UD. Kopi Gepeng',
#  'H+N Coffee',
#  'WARMINDO SURABAYA KOPI',
#  'Casa Coffee',
#  'Warung Kopi Stela',
#  'Rindu Kopi Senja - Nginden Semolo',
#  'Sult Cafe & Eatery',
#  'De Mandailing Cafe & Eatery - Kertajaya Indah',
#  'BnD Cafe',
#  'Mojako - Semampir Tengah 4 A',
#  'Borre Cafe',
#  'Konoae Warung A La Cafe, Keputih',
#  'Rodah Coffee Bar and Tea Cafe',
#  'Deckside Lounge & Cafe',
#  'HaHa Cafe mulyosari',
#  'Green Cloud Cafe',
#  'Sand Box Cafe - Pakuwon City Mall',
#  'The Localist Coffee and Bistro Surabaya',
#  'Warung Kopi Mbooud',
#  'Kofie Paste',
#  'Kopi Lain Hati - Keputih',
#  'Kedai Kopi Oy! x BC PSKNBEAT. SBY',
#  'LAKONE Koffie',
#  'Kopi Anak Monopole Klampis',
#  "Bent's Roti Kopi",
#  'Kopi Kenangan - Dharmahusada',
#  'Kopi Anak Monopole - Ngagel',
#  'Aku Dan Kopi',
#  'FULL MOON Cafe and Eatery',
#  'Eicy Cafe',
#  'apollo billiard and cafe',
#  'Harman Cafe',
#  'MADANI CAFE SURABAYA',
#  'OEBIN',
#  'Arra Cafe',
#  'Combi Road Cafe',
#  'Upper Room Cafe & Resto',
#  'Cak Di Cafe & live music',
#  'Bucket and catering ,pangsit mie ayam jakarta',
#  'Pangsit Mie Bangka Mulyorejo',
#  'Mie Asui 168',
#  'Mie Ayam dan Bakso Solo Ning Ati',
#  'Bakso, Pangsit, Mie Ayam Ning Ati',
#  'Mie Tokyo Chinese Food',
#  'Pangsit Mie Ayam Mas Eko',
#  'Depot Kwan Mie Keriting & Kwetiau Medan',
#  'PANGSIT MIE CAHAYA',
#  'Medicine Cafe',
#  'Point Cafe Dharmahusada 62',
#  'Garasi 1/2 Cafe and Eatery',
#  'Eleven Cafe',
#  'Ambyar cafe',
#  'Cafe Isen',
#  'Fortitude Bound by Loyalty',
#  'VARASH SURABAYA',
#  'Ludic Cafe Semolo',
#  'Kedai Rhythm',
#  'Strike Pool & Cafe',
#  'Point Cafe Dharmawangsa 41',
#  'Cafe Nusa Indah',
#  'Kedai Mino',
#  'Kedai Cemoro',
#  'Kedai MID',
#  'Kedai Rino Wengi',
#  'Kedai Dulur Dewe',
#  'KEDAI Pi-toe Pi-toe',
#  'Kedai Letole',
#  "KEDAI DO'A IBU",
#  'Kedai Ciamso 2.0',
#  'Kedai ORI Manyar',
#  'Kedai ButonG',
#  'Pangsit Mie Ayam Tuban',
#  'Mie Gever 25',
#  'MIE REDJO KTT',
#  'Pangsit Mie Ayam Jakarta Bu Tin',
#  'MIE ADONAI',
#  'MIE DHOHO',
#  'Comfy Laundry & Cafe',
#  'Manna Cafe',
#  'Cafe 18',
#  'Konoae Warung A La Cafe, Klampis Ngasem',
#  'Café Airlangga',
#  'Aume Cafe',
#  'cafe K3 coffeety first',
#  'Nio Billiard & Cafe',
#  'Baskhara Cafe',
#  'TERAS CAFE 73 (STMJ - KOPI - SUSU)',
#  'Cafe 94',
#  'Homu Cafe',
#  'BASS COFFEE & EATERY',
#  'Mesthi Cafe',
#  'CAFE HAUS',
#  'Kedai MARTOREDJO',
#  'Kedai Zhuka',
#  'Kedai Soekatjita Selaloe',
#  'Kedai Kita',
#  'Kedai Kopi Pancing Cak Wid',
#  'Kedai Kopi Sedjalan',
#  'Kedai Zoom',
#  'Depot Bu Rudy - Dharmahusada',
#  'Depot 52 Prasmanan',
#  'Depot Klampis G-160',
#  'Depot Pak Bas',
#  'Depot J-One',
#  'Depot',
#  'Depot Family',
#  'Depot AA',
#  'Depot Tombo Luwe',
#  'Depot Ratu',
#  'Depot Ny Kim',
#  'Depot Gang Djangkrik Manyar Kertoarjo Surabaya',
#  'Depot Pawon Ijo',
#  'Depot 55',
#  'Depot Icha',
#  'Kedai Senja Kopi 2',
#  'Kedai Kopi Cengengesan',
#  'Kedai Senja Kopi',
#  'Kedai Veskopi',
#  'Kedai kopi',
#  'Kedai Warkop "Kopi Lawas"',
#  'Kedai 27 Derajad',
#  'KEDAI KOPI JOSS RENSY',
#  'Kedai Sumber Bahagia',
#  'Kedai Summerr',
#  'Kedai Hutan Tropis',
#  'Warteg Putri Sami Asih Semolowaru',
#  'Warteg Bu Erni',
#  'Warteg Aero Sukolilo',
#  'Warteg Orens Bahari 150 - Semolowaru',
#  'Kharisma Bahari Charis',
#  'Warteg Kekinian',
#  'WARTEG SAMI ASIH',
#  'Warung Bu Tari',
#  'Warteg',
#  'Warteg ITA Barokah',
#  'Depot Kang Ran 78',
#  'Depot Mentari',
#  'Depot Slamet',
#  'Depot Anugerah',
#  'Depot Monika Rasa',
#  'Depot 539',
#  'Depot Mulyosari 212 Khas Madura (Ibu Choirul Anam)',
#  'Depot Cak Win',
#  'Kedai Van Djava',
#  'Coffee Times',
#  'Kedai Kopi 7',
#  'Kedai Kopi Adat',
#  'Kedai Kopi Serupa',
#  'Kedai Kopi Rimba',
#  'Kedai Semampir',
#  'Kedai Fannis',
#  'Kedai Kopi Tugas Negara - Dharmawangsa',
#  'Kedai Ori San Antonio',
#  'Kedai Kopi & STMJ 5758',
#  'Kedai Warkop Sobat Sejati',
#  'Warkop Kedai Gaul',
#  'Kedai STMJ',
#  'Warteg Orens Bahari 135 - Karang Menjangan',
#  'Warteg Merdeka 45',
#  'WARTEG KHARISMA BAHARI RGP',
#  'WARTEG ORENS BAHARI',
#  'Warung Makan Tegal',
#  'Warung Makan AERO BANGKIT 24 Jam',
#  'Warteg Naik Kelas',
#  'Depot Bedjo',
#  'Depot Pak Min',
#  'Depot Gentong Mas',
#  'Depot ARTO MORO',
#  'Depot Victory',
#  'Depot Langgeng',
#  'Depot Langgeng Jaya',
#  'Depot Mandarin 2',
#  'Depot Lumintu Dinoyo',
#  'Depot Mustikarasa',
#  'Depot Pak Umbar',
#  'Warteg sri sadana',
#  'Warteg sri sadana',
#  'Warteg Sri Sadana',
#  'Warung Selera Bahari Nginden Semolo',
#  'Warteg Lapan',
#  'Warung Bu Mar (Ibuk Marsiati)',
#  'Warung Makan SK',
#  'Kedai boba',
#  'Kedai Jiali',
#  'Warkop Kedai Kopi Djoeang',
#  'Kedai kopi gebang 21',
#  'Kedai Nong-kie',
#  'Kedai Jenggot Putih',
#  'Depot favor-it',
#  'Depot Mahkota',
#  'Depot Cak Bas',
#  'Depot Sumber Sari',
#  'Depot "Chi-Ki" Bu Liem',
#  'Depot PKL Mega Galaxy',
#  'Depot Terasa Nikmat Gubeng',
#  'Depot Dapur Masakan Malaysia (Chinese Food) "Cak WONDO"',
#  'Depot sam',
#  'Depot Hongkong San Diego Pakuwon City',
#  'Depot Saudara (Chinese Food)',
#  'Warung Nasi Uduk & Nasi Campur "Bambu Pojok"',
#  'Warkop Unyil - Tempat nongkrong dan ngopi asik',
#  'Warkop 4K',
#  'Warkop Sholawat Bang Azis',
#  'Warkop Goeboeg 99',
#  'Warkop Klampis Jaya (WARPOL)',
#  'WARKOP JSS 99',
#  'Warkop Not Café',
#  'WARKOP WKS',
#  'Warkop GW27 (Cak Tik)shodakoh ekoh',
#  'Warkop Cak Ron',
#  'Warkop Magesta',
#  'Warkop Cak Kin',
#  'Warkop TKP',
#  'Warkop Cangkruk Pojok Tegar',
#  'WARKOP KS (Kopi Selir) Semampir',
#  'Warkop Klewer',
#  'Warkop Damis 77',
#  'Depot Pak Min',
#  'Depot Naga',
#  'Depot Pak Min',
#  'Depot M91',
#  'SATE HALIM',
#  'Raja Sate',
#  'Sate Ayam Manyar Indah Pak Sali',
#  'warung sate pak breng',
#  'Sate Taichan 88',
#  'Sate Madura Enak',
#  'Pigmalion - Kertajaya Indah',
#  'Sate Ayam Cak Sul',
#  'Sate Pak Imam Depan Polsek',
#  'Sate Ayam Madura "Bang Kumis"',
#  'Raja Sate dan Soto',
#  'Sate Ayam Ponorogo Pak Seger',
#  "Sate Pak Mat Jami'i",
#  'Sate Klopo Kak Mad',
#  'Sate & Gule Cak Wit',
#  'Sate "Sinar Jaya"',
#  'Sate pak Ali madura',
#  'Sate Padang Palapa',
#  'sate madura umar',
#  'Soto Ayam Lamongan CAK HAR',
#  'Restoran Padang Sederhana - Kertajaya',
#  'DEPOT SEDERHANA (GUBENG POJOK)',
#  'Dapoer Kecombrang Surabaya - Wonorejo Timur',
#  'Wapo Resto',
#  'Boncafe - Pregolan',
#  'Domicile Kitchen And Lounge',
#  'de Soematra',
#  'Tokyo Resto 68',
#  'Arumanis Restaurant',
#  'Hanamasa - Gubeng Pojok',
#  'Rumah Makan Layar Seafood Manyar',
#  'Sate House Bogowonto',
#  'Sate dan Gulai Kambing Pucan',
#  'sate pak sabar',
#  'Sate Plecing Bli Kesuma',
#  'Taichan Nyot2',
#  'Sate Madurasa',
#  'Sate Padang Sinar Gemilang Djo Siin',
#  'Sate Ayam GBT',
#  'Sate Cak Seger Ponorogo',
#  '"Warung Sate Berkah Rasa" Semolowaru Elok',
#  'Sate Babi Halim',
#  'WarKop KM 135',
#  'WARKOP JAYADI (JAYA ABADI)',
#  'Warkop waduk barata jaya ( ptt )',
#  'WARKOP CAK DIN DAN CAK DUL',
#  'Warkop Aji Raja Kopi',
#  'Warkop Berkah (Warung Skena)',
#  'Warkop Dua Dunia',
#  'Warkop Pemuda Songolaz (WPS)',
#  'Warkop Ramonez',
#  "Soto Ayam Kampung Cak Mu'in",
#  'Soto Ayam cak di Lamongan',
#  'Soto ayam lamongan cak Har ( PUSAT )',
#  "Soto Ayam Pak Yan's",
#  'Soto Madura Dan Soto Ayam H. Syafik Arief Rahman Hakim (Warung Makan Soto, Soto Madura Asli, Soto Daging Madura, Soto Ayam)',
#  'Soto Kwali Solo Pak Wasis',
#  "Soto ayam n'desso",
#  'Soto Ayam Cak Nuris',
#  'Soto Gubeng PJKA ASLI',
#  'Soto Ayam Lamongan Cak To',
#  'Soto Banjar Selera Kita',
#  'Soto Ayam Cak Wid',
#  'Soto Ayam Lamongan Cak Agus',
#  'SATE AYAM KELAPA WARISAN',
#  'Warung Sate Pak Yusup Pinggir Jembatan',
#  'Sate Madura Kak Mad',
#  'Gule Kambing, Sate Kambing, Ayam',
#  'Sate Padang Duo Putri',
#  'Sate Ayam & Gule Cak Sahar',
#  'Sate Manyar Kalisari',
#  'Glory Sate Babi',
#  'SATE JOKO TOLE Madura',
#  'Sate Ayam Sate Kambing Pak Buser',
#  'Sate Ayam dan Kambing Madura',
#  "JJ's Sate Babi",
#  'Sate ayam pak syafii',
#  'SHAO KAO',
#  'Sari Laut Cak Aris Khas Lamongan',
#  'Ikan bakar keputih kh ahmad dahlan',
#  'SAS Cafe N Resto',
#  'Aneka Sate Mertua',
#  'Bu mar sate ayam dan sate taichan khas madura',
#  'Sate Taichan Sataichan',
#  'Sate Ayam Madura Pak Sayidi -Gubeng',
#  'Sate Ayam Pak Topan',
#  'Sate Ayam Cak Kolil',
#  'Soto Ayam Lamongan Cak Tono',
#  'Soto Ayam Pak Umar Kertajaya',
#  'Soto Ayam Kampung Pak Djayus',
#  'Soto Ayam Lamongan Cak Yadi',
#  'Soto Ayam Lamongan Cak Lan',
#  'Soto Tapak Siring',
#  'Soto Daging Cak Toha',
#  'Soto Ayam Lamongan Pak Salam',
#  'Ayam Bakar Primarasa Manyar Kertoarjo',
#  'Bima Restaurant',
#  'CARNIS - Gubeng',
#  'JOYBOX RESTO & LOUNGE',
#  'Nasi Pecel Rawon Pucang Moroseneng',
#  'Resto Padang Simpang Raya',
#  'WARKOP SEMAR',
#  'Warkop Balazyk',
#  'Warkop Bang Rudy',
#  'Warkop Gairah Muda',
#  'Warkop Putra Kelud',
#  'WarKop KM 35',
#  'Warkop 29 RIZKI Free WIFI',
#  'Warkop ALASKA',
#  'WARKOP TERAS 72',
#  'Warkop & Billiard GalGol',
#  'Soto Madura Tropicana',
#  'Soto Ayam Akbar',
#  'Soto Madura Gubeng PJKA',
#  'Soto Ayam Cak Imron',
#  'Kapulogo - Soto Ayam Kampung',
#  'Soto Banjar Cik Moy',
#  'Soto Ayam Pak NOTO Dharwangsa',
#  'Soto Ayam Cak Nan',
#  'Soto Ayam Pak Erick',
#  'Soto Ayam Surabaya Cak Kurnia',
#  'Soto Ayam Lamongan Cak Men Ipiems',
#  "D'Jawa Cafe & Resto",
#  'Kakkoii All You Can Eat Japanese BBQ & Shabu-Shabu, Surabaya, Manyar',
#  'Rumah Makan Idaman - Manyar Kertoarjo 5',
#  'Tahu Telor Pak Jayen Cabang Dharmahusada',
#  'ONKEI Restoran Jepang',
#  'Warkop Hilal',
#  'Warkop Sham',
#  'Warkop Barata',
#  'Warkop abimanyu',
#  'Warkop Gresik Semolowaru',
#  'WARKOP GAYAM',
#  'Warkop 02 Safaraz',
#  'Warkop adi',
#  'Warkop Cak Kasnun',
#  'WARKOP 3000',
#  'Warkop 78 & TOKO IVA',
#  'Warkop R-11',
#  'Warkop DKN',
#  'Warkop Lestari']

# %% [markdown]
# # preprocessing data jarak

# %%
#Install library untuk hitung jarak dari kampus
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (2.9.0)
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\LENOVO\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
df['location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 681 entries, 0 to 680
# Series name: location
# Non-Null Count  Dtype
# --------------  -----
# 681 non-null    object
# dtypes: object(1)
# memory usage: 5.4+ KB

# %%
df['location'] = df['location'].apply(ast.literal_eval)

# %%
df['location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 681 entries, 0 to 680
# Series name: location
# Non-Null Count  Dtype
# --------------  -----
# 681 non-null    object
# dtypes: object(1)
# memory usage: 5.4+ KB

# %%
#bujur dan lintang kampus a, b, dan c unair
kampus_a = (-7.2755,112.7634)
kampus_b = (-7.2713, 112.7688)
kampus_c = (-7.2697,112.7848)

# %%
#hitung jarak dalam satuan km dari kampus c
df['Jarak_KampusC'] = df['location'].apply(lambda x : haversine(kampus_c,( x['lat'], x['lng']), unit = Unit.KILOMETERS), 2)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_32312\2451219098.py:2: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   df['Jarak_KampusC'] = df['location'].apply(lambda x : haversine(kampus_c,( x['lat'], x['lng']), unit = Unit.KILOMETERS), 2)

# %%
#hitung jarak dalam satuan km dari kampus b
df['Jarak_KampusB'] = df['location'].apply(lambda x : haversine(kampus_b,( x['lat'], x['lng']), unit = Unit.KILOMETERS),2)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_32312\284811816.py:2: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   df['Jarak_KampusB'] = df['location'].apply(lambda x : haversine(kampus_b,( x['lat'], x['lng']), unit = Unit.KILOMETERS),2)

# %%
#hitung jarak dalam satuan km dari kampus a
df['Jarak_KampusA'] = df['location'].apply(lambda x : haversine(kampus_a,( x['lat'], x['lng']), unit = Unit.KILOMETERS),2)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_32312\3958307159.py:2: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   df['Jarak_KampusA'] = df['location'].apply(lambda x : haversine(kampus_a,( x['lat'], x['lng']), unit = Unit.KILOMETERS),2)

# %%
df
# Out:
#                            title  \
# 0         Bakso CITRA SATU PUTRA
# 1       Bakso asli solo Pak Tono
# 2                Bakso Pak Anton
# 3              Bakso Kepala Sapi
# 4    Warung Bakso Dan Mie Wijaya
# ..                           ...
# 676                  WARKOP 3000
# 677         Warkop 78 & TOKO IVA
# 678                  Warkop R-11
# 679                   Warkop DKN
# 680               Warkop Lestari
#
#                                                address  totalScore  \
# 0    Jl. Raya Mulyosari No.177-179, Kalisari, Kec. ...         4.7
# 1    Jl. Gebang Lor No.49, Gebang Putih, Kec. Sukol...         4.5
# 2    Jl. Wisma Permai Tengah I No.CC-21, Kejawaan P...         4.8
# 3    Jl. Klampis Jaya No.47, Klampis Ngasem, Kec. S...         4.3
# 4    Jl. Mulyorejo Tengah No.73, Mulyorejo, Kec. Mu...         4.5
# ..                                                 ...         ...
# 676  Jl. Semolowaru No.44, Semolowaru, Kec. Sukolil...         4.4
# 677  Depan parkiran kampus unair B, Jl. Srikana No....         5.0
# 678  Jl. Semolowaru Elok No.11 blok R, Semolowaru, ...         4.8
# 679  Jl. Medokan Semampir AWS No.22, RT.001/RW.006,...         4.6
# 680  Jl. Menur Pumpungan III No.31B, Menur Pumpunga...         4.9
#
#                       categories                                 location  \
# 0                 Restoran Bakso  {'lat': -7.2707337, 'lng': 112.7969433}
# 1                 Restoran Bakso  {'lat': -7.2812233, 'lng': 112.7873977}
# 2     Restoran Bakso Rumah Makan  {'lat': -7.2741205, 'lng': 112.7868231}
# 3                 Restoran Bakso    {'lat': -7.28232, 'lng': 112.7763487}
# 4    Restoran Bakso Restoran Mie  {'lat': -7.2678847, 'lng': 112.7780222}
# ..                           ...                                      ...
# 676                         Kafe  {'lat': -7.3006098, 'lng': 112.7743827}
# 677                   Kedai Kopi  {'lat': -7.2741453, 'lng': 112.7584342}
# 678                   Kedai Kopi    {'lat': -7.307254, 'lng': 112.775239}
# 679                   Kedai Kopi  {'lat': -7.3097995, 'lng': 112.7772405}
# 680                   Kedai Kopi  {'lat': -7.2880431, 'lng': 112.7657127}
#
#      Jarak_KampusC  Jarak_KampusB  Jarak_KampusA
# 0         1.344342       3.104870       3.737606
# 1         1.312979       2.329260       2.722356
# 2         0.539819       2.012544       2.588117
# 3         1.684682       1.481480       1.617075
# 4         0.774372       1.085798       1.821619
# ..             ...            ...            ...
# 676       3.623989       3.316764       3.043539
# 677       2.949874       1.186320       0.568064
# 678       4.306918       4.060499       3.764608
# 679       4.536154       4.381010       4.108095
# 680       2.931306       1.892636       1.417866
#
# [681 rows x 8 columns]

# %%
df.to_csv('data_resto_with_jarak.csv', index= False)

# %% [markdown]
# # **Feature Extraction**

# %%
#tf idf untuk  sama catgories
data = df.copy()
tfidf = TfidfVectorizer()
data['combined'] = data['categories'] +' '+ data['title']
data['combined'] = data['combined'].apply(remove_symbol)

joblib.dump(tfidf, 'tfidf.pkl')

tfidf_categories = tfidf.fit_transform(data['combined'])

joblib.dump(tfidf_categories, 'tfidf_matrix.pkl')
# Out:
# ['tfidf_matrix.pkl']

# %%
data['combined']
# Out:
# 0                  Restoran Bakso Bakso CITRA SATU PUTRA
# 1                Restoran Bakso Bakso asli solo Pak Tono
# 2             Restoran Bakso Rumah Makan Bakso Pak Anton
# 3                       Restoran Bakso Bakso Kepala Sapi
# 4      Restoran Bakso Restoran Mie Warung Bakso Dan M...
#                              ...
# 676                                         Kafe WARKOP
# 677                         Kedai Kopi Warkop   TOKO IVA
# 678                                  Kedai Kopi Warkop R
# 679                                Kedai Kopi Warkop DKN
# 680                            Kedai Kopi Warkop Lestari
# Name: combined, Length: 681, dtype: object

# %%
cosin = cosine_similarity(tfidf_categories)
cosin_df = pd.DataFrame(
    cosin,
    index= data['combined'],
    columns= data['combined']
)

joblib.dump(cosin_df, 'cosinesimilarity.pkl')
# Out:
# ['cosinesimilarity.pkl']

# %%
cosin_df.dtypes
# Out:
# combined
# Restoran Bakso Bakso CITRA SATU PUTRA                      float64
# Restoran Bakso Bakso asli solo Pak Tono                    float64
# Restoran Bakso Rumah Makan Bakso Pak Anton                 float64
# Restoran Bakso Bakso Kepala Sapi                           float64
# Restoran Bakso Restoran Mie Warung Bakso Dan Mie Wijaya    float64
#                                                             ...
# Kafe WARKOP                                                float64
# Kedai Kopi Warkop   TOKO IVA                               float64
# Kedai Kopi Warkop R                                        float64
# Kedai Kopi Warkop DKN                                      float64
# Kedai Kopi Warkop Lestari                                  float64
# Length: 681, dtype: object

# %%
cosin_df.columns = cosin_df.columns.str.strip().str.lower()
cosin_df.index = cosin_df.index.str.strip().str.lower()

cosin_df.index
# Out:
# Index(['restoran bakso bakso citra satu putra',
#        'restoran bakso bakso asli solo pak tono',
#        'restoran bakso rumah makan bakso pak anton',
#        'restoran bakso bakso kepala sapi',
#        'restoran bakso restoran mie warung bakso dan mie wijaya',
#        'restoran bakso restoran mie bakso  mie bondowoso',
#        'restoran mie restoran bakso bakso pangsit mie ayam sensasi rasa',
#        'restoran bakso restoran mie bakso dan mie ayam barokah',
#        'restoran bakso restoran mie bakso solo goyang lidah goli',
#        'restoran bakso bakso bem',
#        ...
#        'kedai kopi kafe warkop gresik semolowaru', 'kafe warkop gayam',
#        'kafe seni warkop  safaraz', 'kedai kopi warkop adi',
#        'kedai kopi warkop cak kasnun', 'kafe warkop',
#        'kedai kopi warkop   toko iva', 'kedai kopi warkop r',
#        'kedai kopi warkop dkn', 'kedai kopi warkop lestari'],
#       dtype='object', name='combined', length=681)

# %%
def display_name(category_query, similarity_df, item_data,base,  k=5):
    category_query = category_query.strip().lower()
    
    # Cari kolom similarity yang cocok berdasarkan string
    matched_cols = [col for col in similarity_df.columns if category_query in col.lower()]
    
    if not matched_cols:
        print(f"Tidak ditemukan hasil untuk kategori: '{category_query}'")
        return pd.DataFrame()

    selected_col = matched_cols[0]
    similarity = similarity_df[selected_col]

    top_k = similarity.nlargest(k)
    top_k = top_k.groupby(level= 0).max()
    ## print(top_k)

    # Persiapan data
    item_data['categories_cleaned'] = item_data['categories'].apply(remove_symbol)
    item_data['title_cleaned'] = item_data['title'].apply(remove_symbol)
    item_data['combined'] = item_data['categories_cleaned'] + ' ' + item_data['title_cleaned']
    item_data['combined'] = item_data['combined'].str.strip().str.lower()
    ##print(top_k.index.tolist())

    #print(item_data['combined'].tolist()[:10])  # tampilkan 10 data awal

    # Ambil yang cocok berdasarkan index di top_k
    recom = item_data[item_data['combined'].isin(top_k.index)].copy()

    ##print(recom[['combined']])
    #missing_items = set(top_k.index) - set(item_data['combined'])
    #print("Tidak ditemukan di item_data:", missing_items)
    recom['similarity'] = recom['combined'].map(top_k)

    #hitung jarak dari kampus mana
    base_column = f'Jarak_Kampus{base.upper()}'
    if base_column not in recom.columns:
        print(f"Masukkan dari UNAIR Kampus Mana")
    else:
        recom = recom.sort_values(by= [base_column], ascending= True)
    #ambil berdasarkan rating tertinggi dan similarity tertinggi 
    return recom.sort_values(by=[f'{base_column}','totalScore', 'similarity'], ascending=[True, False, False])

# %%
display_name(
    category_query= 'sate',
    similarity_df= cosin_df,
    item_data= df,
    base= 'C',
    k= 5
)
# Out:
#                                 title  \
# 540                        SATE HALIM
# 576                     Sate Madurasa
# 613  Sate Ayam Sate Kambing Pak Buser
# 541                         Raja Sate
# 581                   Sate Babi Halim
#
#                                                address  totalScore  \
# 540  Jl. Manyar Kertoarjo No.114, RT.001/RW.06, Man...         4.7
# 576  Jl. Raya Menur No.5, Mojo, Kec. Gubeng, Suraba...         4.1
# 613  Jl. Manyar Rejo I No.2, RT.001/RW.05, Menur Pu...         4.8
# 541  Jl. Semolowaru Tengah I No.62, Semolowaru, Kec...         5.0
# 581  Jl. Raya Manyar No.84, Baratajaya, Kec. Gubeng...         4.3
#
#         categories                                 location  Jarak_KampusC  \
# 540  Restoran Sate  {'lat': -7.2806375, 'lng': 112.7711573}       1.934818
# 576  Restoran Sate  {'lat': -7.2753229, 'lng': 112.7625344}       2.534247
# 613  Restoran Sate  {'lat': -7.2940424, 'lng': 112.7642162}       3.532852
# 541  Restoran Sate  {'lat': -7.3039676, 'lng': 112.7787338}       3.868686
# 581  Restoran Sate  {'lat': -7.2979585, 'lng': 112.7618416}       4.035567
#
#      Jarak_KampusB  Jarak_KampusA categories_cleaned  \
# 540       1.070345       1.028803      Restoran Sate
# 576       0.823236       0.097485      Restoran Sate
# 613       2.578888       2.063788      Restoran Sate
# 541       3.794123       3.588939      Restoran Sate
# 581       3.062040       2.503183      Restoran Sate
#
#                         title_cleaned  \
# 540                        SATE HALIM
# 576                     Sate Madurasa
# 613  Sate Ayam Sate Kambing Pak Buser
# 541                         Raja Sate
# 581                   Sate Babi Halim
#
#                                            combined  similarity
# 540                        restoran sate sate halim    1.000000
# 576                     restoran sate sate madurasa    0.549985
# 613  restoran sate sate ayam sate kambing pak buser    0.551117
# 541                         restoran sate raja sate    0.576401
# 581                   restoran sate sate babi halim    0.854884
